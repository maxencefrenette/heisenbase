# %%
import pandas as pd

pd.set_option("display.max_rows", None)
pd.read_parquet("../data/pgn_index.parquet")
# Out:
#                  material_key  num_games
# 0                  KRPPPvKRPP      86665
# 1                KRPPPPvKRPPP      73384
# 2                    KRPPvKRP      72574
# 3                   KRPPPvKRP      48368
# 4                 KRPPPvKRPPP      47594
# 5                   KRPPvKRPP      43473
# 6              KRPPPPPvKRPPPP      43020
# 7                 KRPPPPvKRPP      39647
# 8                     KRPPvKR      39200
# 9               KRPPPPvKRPPPP      36273
# 10                     KRPvKR      35302
# 11                    KRPvKRP      25114
# 12                 KQPPPvKQPP      23796
# 13                       KPvK      23041
# 14              KRPPPPPvKRPPP      22374
# 15               KQPPPPvKQPPP      22176
# 16                 KNPPPvKNPP      19132
# 17                   KRNPvKRP      18519
# 18            KRPPPPPvKRPPPPP      18481
# 19                        KvK      18288
# 20                    KRNPvKR      17679
# 21                  KRNPvKRPP      16832
# ...
