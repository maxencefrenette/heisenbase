# %%
import pandas as pd

pd.set_option("display.max_rows", None)
pd.read_parquet("../data/pgn_index.parquet").head(1000)
# Out:
#     material_key  num_games
# 0            KvK      18288
# 1           KRvK      11316
# 2           KNvK       8201
# 3          KBdvK       7044
# 4          KQvKR       6971
# 5          KRvKR       5705
# 6         KRNvKR       4810
# 7          KRvKN       4548
# 8        KRBdvKR       4084
# 9           KQvK       4026
# 10        KRvKBd       3761
# 11        KRNvKN       3328
# 12         KRNvK       3108
# 13        KRRvKR       3082
# 14         KQvKQ       2914
# 15       KRBdvKN       2885
# 16        KRBdvK       2380
# 17        KBdvKN       2035
# 18         KQvKN       1938
# 19        KBdNvK       1885
# 20       KRg5vKR       1885
# 21      KRBdvKBl       1882
# 22         Kh5vK       1863
# 23       KRg6vKR       1852
# 24         Kh6vK       1819
# 25         KNvKN       1809
# 26        KQRvKR       1802
# 27       KRf5vKR       1634
# 28       KRa6vKR       1617
# 29       KRNvKBd       1570
# 30       KRg4vKR       1522
# 31      KRNh5vKR       1517
# ...
